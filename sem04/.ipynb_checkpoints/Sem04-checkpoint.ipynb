# %% [markdown]
# # Семинар № 4. Введение в МО 2.

# %% [markdown]
# План
# * Метрики качества
# * One-hot-encoding
# * Kaggle
# * RandomSearch
# * feature engeering (Polynomial features)
# * preprocessing
# * scaling
# * create your own classification
# * blending

# %% [markdown]
# ## Создание собственного классификатора в `sklearn`
#
# Чтобы написать собственный классификатор (регрессор), требуется реализовать класс наследующийся от `BaseEstimator` и `ClassifierMixin (RegressorMixin)`.
#
# И реализовать необходимые методы `__init__()`, `fit()`, `predict()`, `predict_proba()`

# %%
from sklearn.base import BaseEstimator

class MyClassifier(BaseEstimator):
    """ A simple exaple of classifier """
    def __init__(self, param, other_param):
        self.param = param
        self.other_param = other_param
        
    def fit(self, X, y):
        """ This should fit classifier. All the "work" should be done here """
        <YOUR CORE HERE>
        return self
    
    def predict(self, X, y=None):
        """ Predict target class for X """
        <YOUR CODE HERE>
        return # prediction values for target
    
    def predict_proba(self, X, y=None):
        <YOUR CODE HERE>
        return # probability
# Out:
#   File "<ipython-input-34-46028510d95d>", line 11
#     <YOUR CORE HERE>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Переобучение

# %%
reg_dtr_over = DTR()
X_test = np.arange(0,10, 0.5)[:,np.newaxis]
plot_reg(X_reg, y_reg, reg_dtr_over, X_test)

# %% [markdown]
# Заметим, что данная функция не сильно похожа на то, что было в реальности ($\mathcal{F} = \sqrt{x}  + sin(x)$) до добавления шума. Это связано с тем, что мы взяли слишком большое пространство решений и выбрали то, которое подходит лучше всего для нашей тестовой выборки, но не факт, что подходит для нас.
#
# Давайте упростим модель.

# %%
reg_dtr_under = DTR(max_depth=7, min_samples_leaf=3)
X_test = np.arange(0,10, 0.5)[:,np.newaxis]
plot_reg(X_reg, y_reg, reg_dtr_under, X_test)

# %% [markdown]
# ## Недообучение

# %%
reg_dtr_under = DTR(max_depth=2)
X_test = np.arange(0,10, 0.5)[:,np.newaxis]
plot_reg(X_reg, y_reg, reg_dtr_under, X_test)

# %% [markdown]
# Если сравним эти 2 модели с реальной функцией $\mathcal{F} = \sqrt{x} + sin(x)$ то получим, что более простая модель по метрике $MAE$
# приближает функцию `лучше`.

# %%
reg_dtr_over.fit(X_reg, y_reg)
reg_dtr_under.fit(X_reg, y_reg)
X_test = np.arange(0, 10, 0.1)[:, np.newaxis]
Y_real = vf(X_test)
Y_over = reg_dtr_over.predict(X_test)
Y_under = reg_dtr_under.predict(X_test)
print(np.abs(Y_real - Y_over).sum(), np.abs(Y_real - Y_under).sum())
# Out:
# 11200.38170686884 11175.734949679203
